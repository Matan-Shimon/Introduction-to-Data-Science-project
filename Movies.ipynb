# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cast = pd.read_csv('cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
# 1

# %%
copy = cast

# %%
hamlet_num = copy.title.value_counts()['Hamlet']
print(hamlet_num)
# Out:
# 299

# %%
# 2

# %%
display(copy.loc[copy['title'] == 'Treasure Island'].sort_values(by='year'))
# Out:
#                    title  year                  name     type  \
# 1312766  Treasure Island  1918       Herschel Mayall    actor
# 3280557  Treasure Island  1918    Eleanor Washington  actress
# 3046750  Treasure Island  1918      Violet Radcliffe  actress
# 1167783  Treasure Island  1918           Raymond Lee    actor
# 1195421  Treasure Island  1918          Elmo Lincoln    actor
# ...                  ...   ...                   ...      ...
# 1663860  Treasure Island  1999  Victor Raider-Wexler    actor
# 1731182  Treasure Island  1999  Scot Thomas Robinson    actor
# 1813707  Treasure Island  1999        Richard Schave    actor
# 2710458  Treasure Island  1999    Stephanie Ittleson  actress
# 815338   Treasure Island  1999          Rio Hackford    actor
#
#                 character     n
# 1312766   Prologue Player   NaN
# 3280557   Prologue Player   NaN
# 3046750  Long John Silver   3.0
# 1167783          Bit Role   NaN
# 1195421   Prologue Player   NaN
# ...

# %%
# 3

# %%
hamlet_1921 = copy.loc[(copy['title'] == 'Hamlet') & (copy['year'] == 1921)]
len(hamlet_1921)
# Out:
# 9

# %%
# 4

# %%
hamlet_decade = copy.loc[copy['title'] == 'Hamlet']
hamlet_decade.groupby(hamlet_decade.year // 10 * 10).size().plot(kind='bar')

# %%
# 5

# %%
leading_roles = copy.loc[(copy['year']//10 == 195) & (copy['n'] == 1)]
leading_roles = leading_roles.groupby(['year' , 'type']).count()[['title']]
leading_roles.columns = ['count']
leading_roles
# Out:
#               count
# year type
# 1950 actor      604
#      actress    271
# 1951 actor      633
#      actress    272
# 1952 actor      591
#      actress    284
# 1953 actor      634
#      actress    290
# 1954 actor      626
#      actress    298
# 1955 actor      606
#      actress    264
# 1956 actor      614
#      actress    288
# 1957 actor      708
#      actress    284
# 1958 actor      694
#      actress    275
# 1959 actor      678
#      actress    287

# %%
# 6

# %%
leadRoles = copy.loc[copy['n'] == 1]
leadRoles = leadRoles[leadRoles.year >= 1990] #Leaving only the movies shown since 1990.
leadActors = (leadRoles.groupby('name').count()).sort_values('title',  ascending=False)[['title']]
leadActors.columns = ['count']
leadActors.head(10)
# Out:
#                     count
# name
# Mohanlal              126
# Mammootty             118
# Akshay Kumar           87
# Jayaram                76
# Andy Lau               72
# Ajay Devgn             69
# Amitabh Bachchan       68
# Eric Roberts           68
# Nagarjuna Akkineni     60
# Dilip                  59

# %%
# 7

# %%
frank_oz = (copy.loc[copy['name'] == 'Frank Oz'].groupby(['year','title']).size()).to_frame()
Frank_Oz_df.columns = ['roles']
Frank_Oz_df.loc[Frank_Oz_df['roles'] > 1].reset_index()
# Out:
#    year                                     title  roles
# 0  1979                          The Muppet Movie      8
# 1  1981            An American Werewolf in London      2
# 2  1981                    The Great Muppet Caper      6
# 3  1982                          The Dark Crystal      2
# 4  1984                The Muppets Take Manhattan      7
# 5  1985  Sesame Street Presents: Follow that Bird      3
# 6  1992                The Muppet Christmas Carol      7
# 7  1996                    Muppet Treasure Island      4
# 8  1999                        Muppets from Space      4
# 9  1999      The Adventures of Elmo in Grouchland      3
